# %%
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]

smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
length = bream_length + smelt_length  
weight = bream_weight + smelt_weight
print(length)
print(weight)
# Out:
# [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0, 31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0, 35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0, 9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
# [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0, 500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0, 700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0, 6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

# %%
length = np.array(bream_length + smelt_length) 
weight = np.array(bream_weight + smelt_weight)
print(length)
print(weight)
len(weight)
# Out:
# [25.4 26.3 26.5 29.  29.  29.7 29.7 30.  30.  30.7 31.  31.  31.5 32.
#  32.  32.  33.  33.  33.5 33.5 34.  34.  34.5 35.  35.  35.  35.  36.
#  36.  37.  38.5 38.5 39.5 41.  41.   9.8 10.5 10.6 11.  11.2 11.3 11.8
#  11.8 12.  12.2 12.4 13.  14.3 15. ]
# [ 242.   290.   340.   363.   430.   450.   500.   390.   450.   500.
#   475.   500.   500.   340.   600.   600.   700.   700.   610.   650.
#   575.   685.   620.   680.   700.   725.   720.   714.   850.  1000.
#   920.   955.   925.   975.   950.     6.7    7.5    7.     9.7    9.8
#     8.7   10.     9.9    9.8   12.2   13.4   12.2   19.7   19.9]
# 49

# %%
from sklearn.model_selection import train_test_split

# 훈련 세트와 테스트 세트로 나눕니다.
train_input, test_input, train_target, test_target = train_test_split(perch_length, perch_weight)

# %%
# 2차원 배열로 만들기

train_input = train_input.reshape(-1,1)
test_input = test_input.reshape(-1,1)
print(length)
# Out:
# [[26.3]
#  [11.3]
#  [31. ]
#  [31.5]
#  [10.5]
#  [10.6]
#  [11. ]
#  [12. ]
#  [25.4]
#  [11.8]
#  [33. ]
#  [11.2]
#  [30. ]
#  [35. ]
#  [33.5]
#  [35. ]
#  [32. ]
#  [29.7]
#  [34.5]
#  [11.8]
#  [12.2]
#  [30. ]
#  [32. ]
#  [41. ]
#  [14.3]
#  [26.5]
#  [36. ]
#  [36. ]
#  [41. ]
#  [29.7]
#  [12.4]
#  [32. ]
#  [38.5]
#  [29. ]
#  [38.5]
#  [15. ]]

# %%
# 특정 범위 밖의 예측이 안되는 문제 -> KNeighborsRegressor
print(knr.predict([[42]]))
print(knr.predict([[43]]))
print(knr.predict([[50]]))
print(knr.predict([[100]]))
# Out:
# [[945.]]
# [[945.]]
# [[945.]]
# [[945.]]

# %%
distances, indexes = knr.kneighbors([[50]])

# %%
import matplotlib.pyplot as plt

plt.scatter(train_input, train_target)
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
# 예측에 사용된 이웃 & 예측된 값

plt.scatter(train_input[indexes], train_target[indexes], marker = 'D')
plt.scatter(50, 1033.33333333, marker = '*')
plt.show()

# %%
# 대안 - 위 문제를 해결하기 위한 선형회귀 모둘 사용

from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(train_input, train_target)    #훈련
# Out:
# LinearRegression()

# %%
# 예측

print(lr.predict([[50]]))
print(lr.predict([[100]]))
print(knr.predict([[50]]))
# Out:
# [1138.84035743]
# [2661.03492853]
# [[945.]]

# %%
# 선형 그래츠 그리기   (예측한 무게는 선형)
# 무게 = A * (길이) + B

A = lr.coef_ # 계수
B = lr.intercept_ # 절편, 독립항

plt.scatter(train_input, train_target)
plt.plot([10, 50],  [10 * A + B, 50 * A + B])
plt.scatter(50, 1138.84035743, marker = '^')
plt.xlabel('length')
plt.ylabel('weight')

plt.show()

# %%
lr.predict([[50]]) == A * 50 + B
lr.predict([[15]])
# Out:
# array([73.30415766])

# %%
# 다항회귀 모댈의 그래프 그려보기
train_poly = np.column_stack((train_input ** 2, train_input))
lr = LinearRegression()
lr.fit(train_poly, train_target) 
lr.predict([[(50 ** 2), 50]])
# Out:
# array([1675.28424315])

# %%
# 다항식 : weight = (A * (length)^2) + (B * length) + (c)    # 다항식은 제곱.
print(lr.coef_, lr.intercept_)         #intercept_ : 절편  y=x+4, coef_: 계수
A = lr.coef_[0]
B = lr.coef_[1]
C = lr.intercept_

# 다항식 차트로 그려보기
points = np.arange(0, 51)
plt.scatter(train_input, train_target)
plt.plot(points, (A * points ** 2) + (B * points) + C)
# print(lr.predict([[50 ** 2, 50]])) 
plt.scatter(50, 1675.28424315, marker = '*')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()
# Out:
# [  0.94181037 -14.54792461] 48.15455942213623

# %%
# 모델 저장하기    # 훈련시킨거 model.pkl로 저장함.
import pickle
with open("/home/hun/code/fishregresstion/src/fishregresstion/lr_model.pkl", "wb") as f:
    pickle.dump(lr, f)   # 훈련결과(kn) 저장
